# %%
import os
import cv2
import random
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
# !pip install segmentation-models
# Out:
# 2026-05-03 14:48:12.955962: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777819693.327916      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777819693.435475      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777819694.310535      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777819694.310573      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777819694.310575      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777819694.310578      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl.metadata (938 bytes)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting image-classifiers==1.0.0 (from segmentation-models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.25.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.0.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.15.1)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2026.2.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (26.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (0.4)
# Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1

# %%
# !ls -lah '/kaggle/input/datasets/azizrixsiev/u-net-semantic-segmentation/Semantic segmentation dataset'
root_dir = '/kaggle/input/datasets/azizrixsiev/u-net-semantic-segmentation'
dataset_dir = '/kaggle/input/datasets/azizrixsiev/u-net-semantic-segmentation/Semantic segmentation dataset'
# Out:
# total 4.0K
# drwxr-xr-x 10 nobody nogroup   0 May  3 14:27  .
# drwxr-xr-x  3 nobody nogroup   0 May  3 14:27  ..
# -rw-r--r--  1 nobody nogroup 548 May  3 14:27  classes.json
# drwxr-xr-x  4 nobody nogroup   0 May  3 14:27 'Tile 1'
# drwxr-xr-x  4 nobody nogroup   0 May  3 14:27 'Tile 2'
# drwxr-xr-x  4 nobody nogroup   0 May  3 14:27 'Tile 3'
# drwxr-xr-x  4 nobody nogroup   0 May  3 14:27 'Tile 4'
# drwxr-xr-x  4 nobody nogroup   0 May  3 14:27 'Tile 5'
# drwxr-xr-x  4 nobody nogroup   0 May  3 14:27 'Tile 6'
# drwxr-xr-x  4 nobody nogroup   0 May  3 14:27 'Tile 7'
# drwxr-xr-x  4 nobody nogroup   0 May  3 14:27 'Tile 8'

# %%
"""Cropping and spliting images, masks"""

images_dataset = []
masks_dataset = []
image_patch_size = 256

def preprocess_data(image_type, extension, dataset):
    for tile_id in range(1, 9):
        for img_id in range(1, 10):
            img = cv2.imread(f"{root_dir}/Semantic segmentation dataset/Tile {tile_id}/{image_type}/image_part_00{img_id}.{extension}", 1)
            
            if img is None: continue

            if image_type == "masks":
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            # cropping images (prep before cut)
            h, w, _ = img.shape
            new_h = (h // image_patch_size) * image_patch_size
            new_w = (w // image_patch_size) * image_patch_size
            img = img[:new_h, :new_w]

            # cutting images
            for y in range(0, img.shape[0], image_patch_size):
                for x in range(0, img.shape[1], image_patch_size):
                    patch = img[y:y + image_patch_size, x:x + image_patch_size, :]
                    dataset.append(patch)

preprocess_data('images', 'jpg', images_dataset)
images_dataset = np.array(images_dataset)
images_dataset = images_dataset.astype('float32') / 255.0 # scale images from 0-255 to to 0-1

preprocess_data('masks', 'png', masks_dataset)
                        
print(f"images: {len(images_dataset)}")
print(f"masks: {len(masks_dataset)}")

images_dataset = np.array(images_dataset)
masks_dataset = np.array(masks_dataset)

print(f"images dataset shape: {images_dataset.shape}")
print(f"masks dataset shape: {masks_dataset.shape}")
# Out:
# images: 1305
# masks: 1305
# images dataset shape: (1305, 256, 256, 3)
# masks dataset shape: (1305, 256, 256, 3)

# %%
plt.figure(figsize=(14, 8))
plt.subplot(1, 2, 1)
plt.axis('off')
plt.imshow(images_dataset[0])
plt.subplot(1, 2, 2)
plt.imshow(masks_dataset[0])
plt.axis('off')

plt.show()

# %%
"""Converting labels into rgb values for future model analysis of rgb masks"""

def hex_to_rgb(hex_str):
    hex_str = hex_str.lstrip('#')
    return np.array(tuple(int(hex_str[i:i+2], 16) for i in (0, 2, 4)))

building = hex_to_rgb('#3C1098')
land     = hex_to_rgb('#8429F6')
road     = hex_to_rgb('#6EC1E4')
veg      = hex_to_rgb('#FEDD3A')
water    = hex_to_rgb('#E2A929')
unlab    = hex_to_rgb('#9B9B9B')

print(f"Building: {building}")
print(f"Land:     {land}")
print(f"Road:     {road}")
print(f"Veg:      {veg}")
print(f"Water:    {water}")
print(f"Unlabeled:{unlab}")
# Out:
# Building: [ 60  16 152]
# Land:     [132  41 246]
# Road:     [110 193 228]
# Veg:      [254 221  58]
# Water:    [226 169  41]
# Unlabeled:[155 155 155]

# %%
"""Creating label images consisting of numbers between 0-5 for future validation"""

# create ID map from masks
def rgb_to_label(mask):
    
    label_seg = np.zeros(mask.shape[:2], dtype=np.uint8)
    
    label_seg[np.all(mask == water,    axis=-1)] = 0
    label_seg[np.all(mask == land,     axis=-1)] = 1
    label_seg[np.all(mask == road,     axis=-1)] = 2
    label_seg[np.all(mask == building, axis=-1)] = 3
    label_seg[np.all(mask == veg,      axis=-1)] = 4
    label_seg[np.all(mask == unlab,    axis=-1)] = 5

    return label_seg

labels = []
for i in range(masks_dataset.shape[0]):
    label = rgb_to_label(masks_dataset[i])
    labels.append(label)

labels = np.array(labels)
labels = np.expand_dims(labels, axis=3)

print(f"Labels array shape: {labels.shape}")
# Out:
# Labels array shape: (1305, 256, 256, 1)

# %%
print(labels[1, 0:10, 0:10, 0])
print()
print(np.unique(labels))
# Out:
# [[1 5 5 5 5 5 5 5 5 5]
#  [1 5 5 5 5 5 5 5 5 5]
#  [1 1 5 5 5 5 5 5 5 5]
#  [1 1 5 5 5 5 5 5 5 5]
#  [1 1 5 5 5 5 5 5 5 5]
#  [1 1 1 5 5 5 5 5 5 5]
#  [1 1 1 5 5 5 5 5 5 5]
#  [1 1 1 5 5 5 5 5 5 5]
#  [1 1 1 1 5 5 5 5 5 5]
#  [1 1 1 1 5 5 5 5 5 5]]
#
# [0 1 2 3 4 5]

# %%
"""Splitting images into 80% for training and 20% for testing"""

total_classes = len(np.unique(labels))
print(f"total classes: {total_classes}")

# convert to one-hot encoding
# shape changes from (1305, 256, 256, 1) to (1305, 256, 256, 6)
labels_categorical_dataset = to_categorical(labels, num_classes=total_classes)
master_training_dataset = images_dataset

# split data into 80/20, seed 42 for the same split each run
X_train, X_test, y_train, y_test = train_test_split(
    master_training_dataset, 
    labels_categorical_dataset, 
    test_size=0.20, 
    random_state=42
)

print(f"training Images: {X_train.shape}")
print(f"testing Images:  {X_test.shape}")
print(f"training Labels: {y_train.shape}")
print(f"testing Labels:  {y_test.shape}")
# Out:
# total classes: 6
# training Images: (1044, 256, 256, 3)
# testing Images:  (261, 256, 256, 3)
# training Labels: (1044, 256, 256, 6)
# testing Labels:  (261, 256, 256, 6)

# %%
image_height = X_train.shape[1]
image_width = X_train.shape[2]
image_channels = X_train.shape[3]

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose
from keras.layers import concatenate, BatchNormalization, Dropout, Lambda

# %%
def jaccard_coef(y_true, y_pred): # take the ground thruth and prediction made by the model

    # make numbers one long flat list
    y_true_f = tf.cast(y_true, tf.float32)
    y_pred_f = tf.cast(y_pred, tf.float32)
    y_true_flatten = tf.reshape(y_true_f, [-1])
    y_pred_flatten = tf.reshape(y_pred_f, [-1])
    
    intersection = tf.reduce_sum(y_true_flatten * y_pred_flatten) # overlap, checking whether pred and mask is the same number
    total_area = tf.reduce_sum(y_true_flatten + y_pred_flatten)
    
    union = total_area - intersection
    
    return (intersection + 1e-7) / (union + 1e-7) # 1.0 or 0.0 | true false

# %%
def multi_class_unet_model(n_classes=5, image_height=256, image_width=256, image_channels=1):
    inputs = Input((image_height, image_width, image_channels))
    source_input = inputs

    # sliding 16 lernels of 3 by 3 size over the image and using relu math to identify features
    c1 = Conv2D(16, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(source_input)
    # make the model forget 20% of it's data, so that it does not just remembers things
    c1 = Dropout(0.2)(c1)
    # slide again for a sharper edges
    c1 = Conv2D(16, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c1)
    # shrink image down by 2 to unlock more details
    p1 = MaxPooling2D((2,2))(c1)

    # since we made image smaller, we now have more features to look for, hence we are using 32 kernels now and we will keep adding
    c2 = Conv2D(32, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(p1)
    c2 = Dropout(0.2)(c2)
    c2 = Conv2D(32, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c2)
    p2 = MaxPooling2D((2,2))(c2)

    c3 = Conv2D(64, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c3)
    p3 = MaxPooling2D((2,2))(c3)

    c4 = Conv2D(128, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c4)
    p4 = MaxPooling2D((2,2))(c4)

    c5 = Conv2D(256, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(p4)
    c5 = Dropout(0.2)(c5)
    c5 = Conv2D(256, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c5)

    
    # we are making image bigger by 2 (from 16x16 to 32x32) and then merging it with it's corresponding new size with details
    # which is c4 (32x62)
    u6 = Conv2DTranspose(128, (2,2), strides=(2,2), padding="same")(c5)
    u6 = concatenate([u6, c4])
    # refine the borders after merging
    c6 = Conv2D(128, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c6)

    u7 = Conv2DTranspose(64, (2,2), strides=(2,2), padding="same")(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c7)

    u8 = Conv2DTranspose(32, (2,2), strides=(2,2), padding="same")(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(u8)
    c8 = Dropout(0.2)(c8)
    c8 = Conv2D(32, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c8)

    u9 = Conv2DTranspose(16, (2,2), strides=(2,2), padding="same")(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(u9)
    c9 = Dropout(0.2)(c9)
    c9 = Conv2D(16, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c9)

    # 6 channel probability map, which means we create 6 filters to determine which class pixel belongs to (using probability)
    # softmax is a desicision maker
    outputs = Conv2D(n_classes, (1,1), activation="softmax")(c9)

    # defining a model using all my settings (layers c1-c9)
    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# %%
# defining report type from a model during training
metrics = ["accuracy", jaccard_coef]

# %%
print(image_height)
print(image_width)
print(image_channels)
print(total_classes)
# Out:
# 256
# 256
# 3
# 6

# %%
def get_deep_learning_model():
    return multi_class_unet_model(n_classes=total_classes,
                                 image_height=image_height,
                                 image_width=image_width,
                                 image_channels=image_channels)

# %%
# model declaration
model = get_deep_learning_model()
# model.get_config()
# Out:
# I0000 00:00:1777819763.922390      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1777819763.928297      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
"""
Since model may be focused heavily on detecting "easy" classes, we are implementing total_loss metric
so that we can put a focus of a model into trying to predict hard classes not only easy, e.g model is predicting
water easily but poorly works with roads, simple accuracy function will output 90%+ accuracy if model will be focused on water.
We are also punishing model for bad predictions to make it 'work harder'
"""

os.environ['SM_FRAMEWORK'] = 'tf.keras'
import tensorflow.keras.utils as keras_utils
if not hasattr(tf.keras.utils, 'generic_utils'):
    tf.keras.utils.generic_utils = keras_utils
import segmentation_models as sm

# fair game for all 6 classes
weights = [0.1666, 0.1666, 0.1666, 0.1666, 0.1666, 0.1666]

# punish model
dice_loss = sm.losses.DiceLoss(class_weights=weights)

# set focus to hard classes
focal_loss = sm.losses.CategoricalFocalLoss()

# combination of both
total_loss = dice_loss + (1 * focal_loss)
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
tf.keras.backend.clear_session()

model.compile(optimizer="adam", loss=total_loss, metrics=metrics)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256, 256,  │          0 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      2,320 │ dropout[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │      9,248 │ dropout_1[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │     36,928 │ dropout_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    147,584 │ dropout_3[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │    295,168 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_8[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │    590,080 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    131,200 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │    295,040 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    147,584 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │     32,832 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │     73,792 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │     36,928 │ dropout_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │      8,224 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     18,464 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_14[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │      9,248 │ dropout_7[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      2,064 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │      4,624 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 256, 256,  │          0 │ conv2d_16[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      2,320 │ dropout_8[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │        102 │ conv2d_17[0][0]   │
# │                     │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,941,190 (7.41 MB)
#  Trainable params: 1,941,190 (7.41 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import logging
logger = logging.getLogger('absl')
logger.setLevel(logging.ERROR)
warnings.filterwarnings('ignore')

model_history = model.fit(X_train, y_train,
                          batch_size=16,
                          verbose=1,
                          epochs=70,
                          validation_data=(X_test, y_test),
                          shuffle=False)
# Out:
# Epoch 1/70
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777819778.146728      85 service.cc:152] XLA service 0x7db5c01294d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1777819778.146788      85 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1777819778.146795      85 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1777819779.552000      85 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-05-03 14:49:44.779464: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:49:44.924338: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:49:47.278167: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:49:47.555125: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:49:48.299980: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:49:48.586501: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:49:49.207369: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:49:49.357397: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:49:49.755326: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:49:49.915022: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:49:51.605195: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:49:51.875390: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1777819803.501692      85 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.4951 - jaccard_coef: 0.2293 - loss: 1.0058
# 2026-05-03 14:50:16.329008: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:50:16.608794: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:50:17.255085: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:50:17.542691: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:50:17.832123: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:50:17.979298: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:50:18.318791: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:50:18.473875: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:50:19.400410: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:50:19.543745: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:50:20.088161: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-05-03 14:50:20.363071: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 67s 541ms/step - accuracy: 0.4962 - jaccard_coef: 0.2309 - loss: 1.0055 - val_accuracy: 0.6274 - val_jaccard_coef: 0.3759 - val_loss: 0.9827
# Epoch 2/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6598 - jaccard_coef: 0.3821 - loss: 0.9757 - val_accuracy: 0.7550 - val_jaccard_coef: 0.4821 - val_loss: 0.9488
# Epoch 3/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.7560 - jaccard_coef: 0.5093 - loss: 0.9470 - val_accuracy: 0.7406 - val_jaccard_coef: 0.4975 - val_loss: 0.9528
# Epoch 4/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.7834 - jaccard_coef: 0.5565 - loss: 0.9380 - val_accuracy: 0.7681 - val_jaccard_coef: 0.5426 - val_loss: 0.9431
# Epoch 5/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - accuracy: 0.8044 - jaccard_coef: 0.6002 - loss: 0.9299 - val_accuracy: 0.7503 - val_jaccard_coef: 0.5556 - val_loss: 0.9506
# Epoch 6/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.8146 - jaccard_coef: 0.6220 - loss: 0.9254 - val_accuracy: 0.7676 - val_jaccard_coef: 0.5781 - val_loss: 0.9420
# Epoch 7/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8196 - jaccard_coef: 0.6301 - loss: 0.9234 - val_accuracy: 0.8028 - val_jaccard_coef: 0.6164 - val_loss: 0.9293
# Epoch 8/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 11s 159ms/step - accuracy: 0.8269 - jaccard_coef: 0.6421 - loss: 0.9204 - val_accuracy: 0.8116 - val_jaccard_coef: 0.6284 - val_loss: 0.9262
# Epoch 9/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - accuracy: 0.8333 - jaccard_coef: 0.6514 - loss: 0.9179 - val_accuracy: 0.8180 - val_jaccard_coef: 0.6400 - val_loss: 0.9241
# Epoch 10/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - accuracy: 0.8379 - jaccard_coef: 0.6587 - loss: 0.9162 - val_accuracy: 0.8146 - val_jaccard_coef: 0.6373 - val_loss: 0.9252
# Epoch 11/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8411 - jaccard_coef: 0.6641 - loss: 0.9149 - val_accuracy: 0.8197 - val_jaccard_coef: 0.6461 - val_loss: 0.9233
# Epoch 12/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8427 - jaccard_coef: 0.6661 - loss: 0.9143 - val_accuracy: 0.8107 - val_jaccard_coef: 0.6361 - val_loss: 0.9271
# Epoch 13/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.8465 - jaccard_coef: 0.6734 - loss: 0.9130 - val_accuracy: 0.8176 - val_jaccard_coef: 0.6461 - val_loss: 0.9247
# Epoch 14/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.8486 - jaccard_coef: 0.6770 - loss: 0.9121 - val_accuracy: 0.8146 - val_jaccard_coef: 0.6417 - val_loss: 0.9256
# Epoch 15/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8511 - jaccard_coef: 0.6811 - loss: 0.9111 - val_accuracy: 0.8111 - val_jaccard_coef: 0.6377 - val_loss: 0.9275
# Epoch 16/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8535 - jaccard_coef: 0.6842 - loss: 0.9103 - val_accuracy: 0.8151 - val_jaccard_coef: 0.6390 - val_loss: 0.9241
# Epoch 17/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 11s 159ms/step - accuracy: 0.8495 - jaccard_coef: 0.6821 - loss: 0.9105 - val_accuracy: 0.8243 - val_jaccard_coef: 0.6581 - val_loss: 0.9215
# Epoch 18/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 11s 159ms/step - accuracy: 0.8510 - jaccard_coef: 0.6873 - loss: 0.9096 - val_accuracy: 0.8028 - val_jaccard_coef: 0.6349 - val_loss: 0.9280
# Epoch 19/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8476 - jaccard_coef: 0.6845 - loss: 0.9108 - val_accuracy: 0.8303 - val_jaccard_coef: 0.6634 - val_loss: 0.9188
# Epoch 20/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8540 - jaccard_coef: 0.6968 - loss: 0.9085 - val_accuracy: 0.8446 - val_jaccard_coef: 0.6833 - val_loss: 0.9129
# Epoch 21/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8559 - jaccard_coef: 0.7001 - loss: 0.9073 - val_accuracy: 0.8425 - val_jaccard_coef: 0.6784 - val_loss: 0.9129
# Epoch 22/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8549 - jaccard_coef: 0.7002 - loss: 0.9073 - val_accuracy: 0.8503 - val_jaccard_coef: 0.6833 - val_loss: 0.9102
# Epoch 23/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8543 - jaccard_coef: 0.6966 - loss: 0.9072 - val_accuracy: 0.8520 - val_jaccard_coef: 0.6914 - val_loss: 0.9097
# Epoch 24/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8585 - jaccard_coef: 0.7050 - loss: 0.9054 - val_accuracy: 0.8538 - val_jaccard_coef: 0.6947 - val_loss: 0.9096
# Epoch 25/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8611 - jaccard_coef: 0.7104 - loss: 0.9047 - val_accuracy: 0.8444 - val_jaccard_coef: 0.6830 - val_loss: 0.9129
# Epoch 26/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8603 - jaccard_coef: 0.7088 - loss: 0.9050 - val_accuracy: 0.8426 - val_jaccard_coef: 0.6857 - val_loss: 0.9165
# Epoch 27/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8624 - jaccard_coef: 0.7137 - loss: 0.9043 - val_accuracy: 0.8448 - val_jaccard_coef: 0.6889 - val_loss: 0.9123
# Epoch 28/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8522 - jaccard_coef: 0.6971 - loss: 0.9069 - val_accuracy: 0.8467 - val_jaccard_coef: 0.6901 - val_loss: 0.9122
# Epoch 29/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8629 - jaccard_coef: 0.7155 - loss: 0.9034 - val_accuracy: 0.8380 - val_jaccard_coef: 0.6776 - val_loss: 0.9156
# Epoch 30/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.8639 - jaccard_coef: 0.7173 - loss: 0.9022 - val_accuracy: 0.8548 - val_jaccard_coef: 0.6993 - val_loss: 0.9100
# Epoch 31/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8606 - jaccard_coef: 0.7100 - loss: 0.9040 - val_accuracy: 0.8442 - val_jaccard_coef: 0.6872 - val_loss: 0.9139
# Epoch 32/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8677 - jaccard_coef: 0.7216 - loss: 0.9008 - val_accuracy: 0.8422 - val_jaccard_coef: 0.6846 - val_loss: 0.9158
# Epoch 33/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8654 - jaccard_coef: 0.7183 - loss: 0.9018 - val_accuracy: 0.8570 - val_jaccard_coef: 0.7038 - val_loss: 0.9084
# Epoch 34/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8649 - jaccard_coef: 0.7192 - loss: 0.9017 - val_accuracy: 0.8544 - val_jaccard_coef: 0.7025 - val_loss: 0.9083
# Epoch 35/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8608 - jaccard_coef: 0.7117 - loss: 0.9033 - val_accuracy: 0.8478 - val_jaccard_coef: 0.6924 - val_loss: 0.9106
# Epoch 36/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8633 - jaccard_coef: 0.7165 - loss: 0.9016 - val_accuracy: 0.8567 - val_jaccard_coef: 0.7057 - val_loss: 0.9087
# Epoch 37/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8681 - jaccard_coef: 0.7230 - loss: 0.9004 - val_accuracy: 0.8551 - val_jaccard_coef: 0.7100 - val_loss: 0.9093
# Epoch 38/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8711 - jaccard_coef: 0.7290 - loss: 0.8985 - val_accuracy: 0.8590 - val_jaccard_coef: 0.7097 - val_loss: 0.9066
# Epoch 39/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8730 - jaccard_coef: 0.7330 - loss: 0.8976 - val_accuracy: 0.8557 - val_jaccard_coef: 0.7091 - val_loss: 0.9080
# Epoch 40/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8740 - jaccard_coef: 0.7334 - loss: 0.8976 - val_accuracy: 0.8574 - val_jaccard_coef: 0.7120 - val_loss: 0.9099
# Epoch 41/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8734 - jaccard_coef: 0.7338 - loss: 0.8977 - val_accuracy: 0.8600 - val_jaccard_coef: 0.7134 - val_loss: 0.9061
# Epoch 42/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8753 - jaccard_coef: 0.7378 - loss: 0.8965 - val_accuracy: 0.8559 - val_jaccard_coef: 0.7130 - val_loss: 0.9093
# Epoch 43/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8745 - jaccard_coef: 0.7359 - loss: 0.8972 - val_accuracy: 0.8571 - val_jaccard_coef: 0.7060 - val_loss: 0.9083
# Epoch 44/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8763 - jaccard_coef: 0.7375 - loss: 0.8958 - val_accuracy: 0.8576 - val_jaccard_coef: 0.7123 - val_loss: 0.9074
# Epoch 45/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8770 - jaccard_coef: 0.7391 - loss: 0.8948 - val_accuracy: 0.8606 - val_jaccard_coef: 0.7144 - val_loss: 0.9076
# Epoch 46/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8830 - jaccard_coef: 0.7496 - loss: 0.8930 - val_accuracy: 0.8675 - val_jaccard_coef: 0.7259 - val_loss: 0.9035
# Epoch 47/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8858 - jaccard_coef: 0.7555 - loss: 0.8912 - val_accuracy: 0.8623 - val_jaccard_coef: 0.7211 - val_loss: 0.9057
# Epoch 48/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8863 - jaccard_coef: 0.7566 - loss: 0.8908 - val_accuracy: 0.8625 - val_jaccard_coef: 0.7229 - val_loss: 0.9064
# Epoch 49/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8827 - jaccard_coef: 0.7503 - loss: 0.8930 - val_accuracy: 0.8347 - val_jaccard_coef: 0.6747 - val_loss: 0.9185
# Epoch 50/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8696 - jaccard_coef: 0.7277 - loss: 0.8989 - val_accuracy: 0.8580 - val_jaccard_coef: 0.7115 - val_loss: 0.9050
# Epoch 51/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8784 - jaccard_coef: 0.7420 - loss: 0.8955 - val_accuracy: 0.8623 - val_jaccard_coef: 0.7171 - val_loss: 0.9043
# Epoch 52/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8807 - jaccard_coef: 0.7468 - loss: 0.8937 - val_accuracy: 0.8628 - val_jaccard_coef: 0.7263 - val_loss: 0.9049
# Epoch 53/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8863 - jaccard_coef: 0.7568 - loss: 0.8909 - val_accuracy: 0.8634 - val_jaccard_coef: 0.7255 - val_loss: 0.9067
# Epoch 54/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8885 - jaccard_coef: 0.7613 - loss: 0.8895 - val_accuracy: 0.8650 - val_jaccard_coef: 0.7254 - val_loss: 0.9042
# Epoch 55/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8831 - jaccard_coef: 0.7523 - loss: 0.8928 - val_accuracy: 0.8611 - val_jaccard_coef: 0.7191 - val_loss: 0.9065
# Epoch 56/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8848 - jaccard_coef: 0.7541 - loss: 0.8920 - val_accuracy: 0.8591 - val_jaccard_coef: 0.7198 - val_loss: 0.9078
# Epoch 57/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8906 - jaccard_coef: 0.7659 - loss: 0.8891 - val_accuracy: 0.8648 - val_jaccard_coef: 0.7212 - val_loss: 0.9056
# Epoch 58/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8921 - jaccard_coef: 0.7675 - loss: 0.8883 - val_accuracy: 0.8634 - val_jaccard_coef: 0.7265 - val_loss: 0.9052
# Epoch 59/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8934 - jaccard_coef: 0.7712 - loss: 0.8876 - val_accuracy: 0.8609 - val_jaccard_coef: 0.7195 - val_loss: 0.9075
# Epoch 60/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8937 - jaccard_coef: 0.7709 - loss: 0.8876 - val_accuracy: 0.8576 - val_jaccard_coef: 0.7007 - val_loss: 0.9094
# Epoch 61/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8977 - jaccard_coef: 0.7785 - loss: 0.8858 - val_accuracy: 0.8583 - val_jaccard_coef: 0.7204 - val_loss: 0.9079
# Epoch 62/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9002 - jaccard_coef: 0.7832 - loss: 0.8852 - val_accuracy: 0.8593 - val_jaccard_coef: 0.7145 - val_loss: 0.9083
# Epoch 63/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9012 - jaccard_coef: 0.7850 - loss: 0.8846 - val_accuracy: 0.8594 - val_jaccard_coef: 0.7220 - val_loss: 0.9088
# Epoch 64/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9010 - jaccard_coef: 0.7848 - loss: 0.8855 - val_accuracy: 0.8494 - val_jaccard_coef: 0.7009 - val_loss: 0.9109
# Epoch 65/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8948 - jaccard_coef: 0.7714 - loss: 0.8871 - val_accuracy: 0.8624 - val_jaccard_coef: 0.7230 - val_loss: 0.9072
# Epoch 66/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9026 - jaccard_coef: 0.7881 - loss: 0.8839 - val_accuracy: 0.8599 - val_jaccard_coef: 0.7196 - val_loss: 0.9062
# Epoch 67/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8991 - jaccard_coef: 0.7811 - loss: 0.8850 - val_accuracy: 0.8627 - val_jaccard_coef: 0.7220 - val_loss: 0.9076
# Epoch 68/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9041 - jaccard_coef: 0.7906 - loss: 0.8838 - val_accuracy: 0.8575 - val_jaccard_coef: 0.7137 - val_loss: 0.9093
# Epoch 69/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9067 - jaccard_coef: 0.7956 - loss: 0.8821 - val_accuracy: 0.8540 - val_jaccard_coef: 0.7077 - val_loss: 0.9120
# Epoch 70/70
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9068 - jaccard_coef: 0.7957 - loss: 0.8818 - val_accuracy: 0.8572 - val_jaccard_coef: 0.7177 - val_loss: 0.9110

# %%
def visualize_prediction(model, x_test, y_test):
    idx = random.randint(0, len(x_test)-1)
    
    test_img = x_test[idx]
    ground_truth = y_test[idx]
    
    test_img_input = np.expand_dims(test_img, 0)
    
    prediction = model.predict(test_img_input)
    predicted_mask = np.argmax(prediction, axis=-1)[0]
    
    true_mask = np.argmax(ground_truth, axis=-1)

    plt.figure(figsize=(15, 10))
    
    plt.subplot(1, 3, 1)
    plt.title(f"Satellite Image (Index: {idx})")
    plt.imshow(test_img)
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.title("Ground Truth (The Reality)")
    plt.imshow(true_mask)
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.title("Model Prediction")
    plt.imshow(predicted_mask)
    plt.axis('off')
    
    plt.tight_layout()
    plt.show()

visualize_prediction(model, X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
save_path = '/kaggle/working/model_v1.keras'
model.save(save_path)
print(f"Model saved successfully at: {save_path}")
# Out:
# Model saved successfully at: /kaggle/working/model_v1.keras
